# %%
prompts = '''{"prompt": "A character design reference sheet for Kei, a young girl with black pigtai
ls and a skateboard, wearing a striped t-shirt and a baseball cap. The sheet includes
a full-body turnaround with three views: front-facing, back-facing, and side-facing. A
dditionally, it features close-up facial expressions showing strong emotions: happy, s
ad, angry, and neutral. The style is 3D animation, designed for children's television,
 with bright, expressive features and dynamic poses.", "file": "emotions.png"}
{"prompt":"Kei is standing in a lively park with green trees, benches, and a skate ram
p in the background. She is on her skateboard, looking determined. The environment is
bright and colorful, designed in a 3D animation style for children's television.","fil
e":"6a5279ec-34dc-4106-888d-4937c09b650c.png"}
{"prompt":"Kei is sitting on the ground and crying after scraping her knee while skate
boarding. The character style matches a 3D animated children's television design, with
 exaggerated, expressive features and a bright, colorful environment. The character sh
ould have the same outfit and hairstyle as in the reference, with strong emotional exp
ressions.", "file":"knee.png"}
{"prompt":"Kei is sitting on the ground and crying after scraping her knee while skate
boarding. The character design matches a 3D animated television style, featuring exagg
erated, expressive features.","file":"09e944e4-ff12-4d0a-a4d3-9d8a70e8c120"}
{"prompt": "Kei is performing a kickflip at a skate park, concentrating hard. The char
acter style closely matches a 3D animated television design with expressive, exaggerat
ed features, inspired by the reference image. Her facial expressions and outfit detail
s, including the striped shorts and wristbands, match the reference style.", "file":"s
tance.png"}
{"prompt":"Kei is performing a kickflip at a skate park, concentrating hard. The scene
 is in a bright and colorful 3D animated television style, with exaggerated, expressiv
e features.","file":"cfec00b3-9749-4ba4-a41e-d26f7d8228fa.png"}
{"prompt":"Kei is laying in bed in a messy room. The character design matches the refe
rence sheet, with expressive exaggerated features, thick eyebrows, a slightly mischiev
ous look, and strong emotional expressions. The style is a 3D animated children's tele
vision design with a bright, colorful environment.","file":"24456ef1-5de5-4893-b28f-bf
55706361f6"}
{"prompt":"Kei laying in bed. She has a tired expression, with eyes half-closed and a
slightly open mouth, conveying exhaustion. The scene is viewed from above, with a mess
y room visible around her. The character matches the reference image in skin color, ra
cial features, and hairstyle, ensuring consistency in design. The character style is i
n 3D animated children's television design, with exaggerated, expressive features and
a bright, colorful environment.","file":"room.png"}
{"prompt":"Kei is holding her skateboard beside her. The background is a realistic par
k setting with trees, grass, and a paved walkway. The pose is natural and relaxed, wit
h her legs slightly bent and her hands resting on the bench. The scene is bright and c
olorful, designed in a children's television animation style. The outfit and hairstyle
 should precisely match the reference image.","file":"112d9360-76bc-453e-a07d-0752cd8b
4fe2.png"}
{"prompt":"Kei sits on a park bench in the afternoon. View from behind. She has her sk
ateboard resting beside her. The background is a realistic park setting with trees, gr
ass, and a paved walkway. The pose is natural and relaxed, with her legs slightly bent
 and her hands resting on the bench. The scene is bright and colorful, designed in a c
hildren's television animation style. The outfit and hairstyle should precisely match
the reference image.","file":"93473612-55f5-4a3b-8e46-b2157643e47f"}
{"prompt":"Kei is sitting at a desk with a bored expression. The character style match
es a 3D animated children's television design, with exaggerated, expressive features a
nd a bright, colorful environment.","file":"desk.png"}
{"prompt":"Kei is sitting at a desk with a bored expression. The character style match
es a 3D animated children's television design, with exaggerated, expressive features a
nd a bright, colorful environment.","file":"3.png"}
{"prompt":"Kei is waving at the camera with a friendly expression. The character's pro
portions and style should match the reference image, with exaggerated, expressive feat
ures suitable for a 3D animated children's television design. The environment is brigh
t and colorful.","file":"wave.png"}
{"prompt":"Kei waves at the camera with a friendly expression. The character's proport
ions and style should match the reference image, with exaggerated, expressive features
 suitable for a 3D animated children's television design. The environment is bright an
d colorful.","file":"wave2"}
{"prompt":"A side view of Kei. She is striking a different pose, such as standing conf
idently with one hand on her hip or adjusting her cap. The character's proportions and
 style should match the reference image, with exaggerated, expressive features suitabl
e for a 3D animated children's television design. The environment is bright and colorf
ul.","file":"brim.png"}'''

prompts += """{"prompt":"Kei sits on the floor next to her bed, in her bedroom. She looks content and has a teal skateboard tucked inder her knees.","file":"1.png"}
{"prompt":"Kei from a 3/4ths view, shoulders up, on a plain white background. She has a determined expression.","file":"10.png"}
{"prompt":"Kei looks at the camera with a defiant, frustrated expression. Reference image on a plain grey background.","file":"11.png"}
{"prompt":"Kei stands on her skateboard, one foot hanging off the edge. She faces at an angle to the camera, with a determined expression. High contrast.","file":"12.png"}
{"prompt":"A side view reference of Kei. She is standing in a neutral pose, slightly leaning forward. The background is light grey. High contrast.","file":"13.png"}
{"prompt":"Kei looks to the side and gestures to her forehead. She has a calm expression, and her hair is in a ponytail. The background is plain white. Japanese RPG animation style. High-key, high exposure.","file":"14.png"}
{"prompt":"A view from the waist up as Kei looks to the side and gestures to her forehead. She has a neutral expression, and her hair is tied back in a ponytail. The background is plain white. Japanese RPG animation style. High brightness, low contrast.","file":"15.png"}
{"prompt":"Kei faces away from the viewer at a 3/4ths angle. She stands in a neutral pose with her arms at her sides. The background is grey. Low brightness.","file":"16.png"}
{"prompt":"Kei sits on the ground crying after scraping her knee, which is bandaged. She wears blue overalls and a backpack, and her skateboard lays on the ground behind her. The background is plain periwinkle. Low contrast, low brightness.","file":"17.png"}
{"prompt":"Kei lays in bed, staring up at the ceiling with a bored, pensive expression. The background is fully rendered, showing her bed and bedroom behind her. View from above. High brightness, low contrast.","file":"18.png"}
{"prompt":"Action shot as Kei does a kickflip on her skateboard. She is wearing knee pads and looking to the side with a confident smile. The setting is plain grey.","file":"19.png"}
{"prompt":"Kei crouches on the ground, wearing knee pads and using her arms to balance. She is facing to the side and looking  slightly up at something out of view. She smiles with appreciation. High contrast.","file":"20.png"}
{"prompt":"Young Kei facing away from the camera at a 3/4ths angle. She stands holding her skateboard and smiles. Plain white background. Low brightness.","file":"4.png"}
{"prompt":"Kei waves at the viewer. She has a friendly, smiling expression. Grey background. High saturation, low brightness.","file":"5.png"}
{"prompt":"Full height view of Kei as she holds her skateboard in front of her. She is facing towards the viewer at a 3/4ths angle and smiles. Plain grey background.","file":"6.png"}
{"prompt":"Kei smiles and waves, facing forward directly at the viewer. Her expression is calm. Blue background. High saturation.","file":"7.png"}
{"prompt":"Kei smiles and waves, facing at a 3/4ths angle towards the viewer. Her expression is firendly. Blue background. High saturation.","file":"8.png"}
{"prompt":"Kei faces towrds the viewer from a 3/4ths view, shoulders up, on a plain white background. She has a determined expression. High brightness.","file":"9.png"}
{"prompt":"Pose reference for young Kei, showing her full body on a plain white background. She poses with her skateboard, facing away from the viewer, and waving, facing towards the viewer. In both poses, she smiles and has a relaxed, happy expression.","file":"wave2.png"}"""
prompts = prompts.replace('\n', '')

# %%
import os

for f in sorted(os.listdir()):
    if f.endswith(".png") and f'"{f}"' not in prompts and len(f) < 10:
        cap = input(f)
        print(f'{{"prompt":"{cap}","file":"{f}"}}')
# Out:
# {"prompt":"Expression reference for Kei. She faces at a 3/4ths angle towards the camera and smiles with an open mouth. Her expression is excited and hopeful. High brightness.","file":"2.png"}
